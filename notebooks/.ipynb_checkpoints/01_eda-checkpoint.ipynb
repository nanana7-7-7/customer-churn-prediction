# %% [markdown]
# ## ライブラリの読み込み

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. データの読み込み

# %%
df = pd.read_csv("../data/raw/Telco-Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ### データの基本確認
# まずデータの行数・列数、カラム名、データ型を確認します。

# %%
df.shape
df.columns
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ## 2. 欠損値の確認

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df["TotalCharges"] = df["TotalCharges"].fillna(0)
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
missing_ratio = df.isnull().mean().sort_values(ascending=False)
missing_ratio
# Out:
# customerID          0.0
# gender              0.0
# SeniorCitizen       0.0
# Partner             0.0
# Dependents          0.0
# tenure              0.0
# PhoneService        0.0
# MultipleLines       0.0
# InternetService     0.0
# OnlineSecurity      0.0
# OnlineBackup        0.0
# DeviceProtection    0.0
# TechSupport         0.0
# StreamingTV         0.0
# StreamingMovies     0.0
# Contract            0.0
# PaperlessBilling    0.0
# PaymentMethod       0.0
# MonthlyCharges      0.0
# TotalCharges        0.0
# Churn               0.0
# dtype: float64

# %% [markdown]
# ## 3. 重複データの確認

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 4. 目的変数Churnの確認

# %%
df["Churn"].value_counts()
df["Churn"].value_counts(normalize=True)
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
sns.countplot(data=df, x="Churn")
plt.title("Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Count")
plt.show()

# %%
churn_rate = df["Churn"].value_counts(normalize=True)["Yes"]
print(f"Churn Rate: {churn_rate:.2%}")
# Out:
# Churn Rate: 26.54%

# %% [markdown]
# ### メモ
#
# 目的変数の分布を見ると、解約していない顧客の方が多い。
# そのため、モデル評価では Accuracy だけでなく、Recall や F1-score も確認する必要がある。

# %% [markdown]
# ## 5. 数値変数の確認

# %%
numeric_cols = ["tenure", "MonthlyCharges", "TotalCharges"]

df[numeric_cols].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7043.000000
# mean     32.371149       64.761692   2279.734304
# std      24.559481       30.090047   2266.794470
# min       0.000000       18.250000      0.000000
# 25%       9.000000       35.500000    398.550000
# 50%      29.000000       70.350000   1394.550000
# 75%      55.000000       89.850000   3786.600000
# max      72.000000      118.750000   8684.800000

# %%
for col in numeric_cols:
    plt.figure()
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %% [markdown]
# ## 6.数値変数とChurnの関係

# %%
for col in numeric_cols:
    plt.figure()
    sns.boxplot(data=df, x="Churn", y=col)
    plt.title(f"{col} by Churn")
    plt.xlabel("Churn")
    plt.ylabel(col)
    plt.show()

# %%
for col in numeric_cols:
    plt.figure()
    sns.histplot(data=df, x=col, hue="Churn", kde=True, bins=30)
    plt.show()

# %% [markdown]
# ### メモ
#
# - tenure が短い顧客ほど解約しやすい可能性がある
# - MonthlyCharges が高い顧客は解約率が高い可能性がある
# - TotalCharges は tenure の影響を受けるため、単独

# %% [markdown]
# ## 7. カテゴリ変数の確認
#
# カテゴリ変数の種類と分布を確認します。

# %%
categorical_cols = df.select_dtypes(include="object").columns.tolist()
categorical_cols
# Out:
# ['customerID',
#  'gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
categorical_cols = [col for col in categorical_cols if col not in ["customerID", "Churn"]]
categorical_cols
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
for col in categorical_cols:
    print(f"--- {col} ---")
    print(df[col].value_counts())
    print()
# Out:
# --- gender ---
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64
#
# --- Partner ---
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64
#
# --- Dependents ---
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64
#
# --- PhoneService ---
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64
#
# --- MultipleLines ---
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64
#
# --- InternetService ---
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64
#
# --- OnlineSecurity ---
# OnlineSecurity
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: count, dtype: int64
#
# --- OnlineBackup ---
# OnlineBackup
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: count, dtype: int64
#
# ...

# %% [markdown]
# ## 8. カテゴリ変数と Churn の関係
#
# カテゴリごとの解約数を可視化します。

# %%
for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df, x=col, hue="Churn")
    plt.title(f"{col} vs Churn")
    plt.xlabel(col)

# %%
for col in categorical_cols:
    churn_rate_by_col = df.groupby(col)["Churn"].apply(lambda x: (x == "Yes").mean()).sort_values(ascending=False)
    
    plt.figure(figsize=(8, 4))
    sns.barplot(x=churn_rate_by_col.index, y=churn_rate_by_col.values)
    plt.title(f"Churn Rate by {col}")
    plt.xlabel(col)
    plt.ylabel("Churn Rate")
    plt.xticks(rotation=45)
    plt.show()

# %%
for col in categorical_cols:
    churn_rate_by_col = df.groupby(col)["Churn"].apply(lambda x: (x == "Yes").mean()).sort_values(ascending=False)
    
    plt.figure(figsize=(8, 4))
    sns.barplot(x=churn_rate_by_col.index, y=churn_rate_by_col.values)
    plt.title(f"Churn Rate by {col}")
    plt.xlabel(col)
    plt.ylabel("Churn Rate")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ## 9. 相関の確認
#
# Churnを数値化して、数値変数との相関を確認します。

# %%
df_corr = df.copy()
df_corr["ChurnFlag"] = df_corr["Churn"].map({"No": 0, "Yes": 1})

# %%
corr_cols = ["tenure", "MonthlyCharges", "TotalCharges", "ChurnFlag"]
corr_matrix = df_corr[corr_cols].corr()
corr_matrix
# Out:
#                   tenure  MonthlyCharges  TotalCharges  ChurnFlag
# tenure          1.000000        0.247900      0.826178  -0.352229
# MonthlyCharges  0.247900        1.000000      0.651174   0.193356
# TotalCharges    0.826178        0.651174      1.000000  -0.198324
# ChurnFlag      -0.352229        0.193356     -0.198324   1.000000

# %%
sns.heatmap(corr_matrix, annot=True, cmap="Blues")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## 10. EDA Summary
#
# 今回の探索的データ分析から、以下の傾向が確認できました。
#
# ### 主な発見
#
# 1. 解約していない顧客の方が多く、目的変数にはやや偏りがある
# 2. tenure が短い顧客ほど解約しやすい傾向がある
# 3. Month-to-month 契約の顧客は解約率が高い傾向がある
# 4. MonthlyCharges が高い顧客は解約しやすい可能性がある
# 5. TechSupport や OnlineSecurity がない顧客は解約しやすい可能性がある
# 6. Electronic check を利用している顧客は解約率が高い可能性がある
#
# ### 次のステップ
#
# 次のNotebookでは、以下を行います。
#
# - `TotalCharges` の欠損値処理
# - `customerID` の削除
# - カテゴリ変数のOne-Hot Encoding
# - 学習データとテストデータの分割
# - Logistic Regression, Random Forest, Gradient Boosting の比較
# - Accuracy, Precision, Recall, F1-score, ROC-AUC による評価
